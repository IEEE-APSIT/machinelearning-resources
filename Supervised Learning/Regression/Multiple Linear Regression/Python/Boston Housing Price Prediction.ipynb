# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Boston.csv',encoding = 'utf8')

# %%
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis',
#        'rad', 'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0',inplace = True)

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# df.columns

# %%
df.dropna(axis = 1, how = 'any')
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.hist(bins = 10, figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A57BCFBDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57BCFC708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D3F1448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D42A308>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D463108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D497F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D4CFE08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D509C88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D519408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D553388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D5B57C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D5ED688>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D627508>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D660388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D6991C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A57D6D3108>]],
#       dtype=object)

# %%
cor=df.corr()
plt.figure(figsize=(20,10))
sns.heatmap(cor[(cor >= 0.5) | (cor <= -0.4)],annot=True,cmap='Blues')

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Including all feilds in the model

# %%
X = df.iloc[:,:-2]
Y = df.iloc[:,-1]

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black
# 0       15.3  396.90
# 1       17.8  396.90
# 2       17.8  392.83
# 3       18.7  394.63
# 4       18.7  396.90
# ..       ...     ...
# 501     21.0  391.99
# 502     21.0  396.90
# 503     21.0  396.90
# 504     21.0  393.45
# 505     21.0  396.90
#
# [506 rows x 12 columns]

# %%
Y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.33)

# %%
X_test
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 439   9.39063   0.0  18.10     0  0.740  5.627   93.9  1.8172   24  666
# 118   0.13058   0.0  10.01     0  0.547  5.872   73.1  2.4775    6  432
# 348   0.01501  80.0   2.01     0  0.435  6.635   29.7  8.3440    4  280
# 385  16.81180   0.0  18.10     0  0.700  5.277   98.1  1.4261   24  666
# 129   0.88125   0.0  21.89     0  0.624  5.637   94.7  1.9799    4  437
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 371   9.23230   0.0  18.10     0  0.631  6.216  100.0  1.1691   24  666
# 84    0.05059   0.0   4.49     0  0.449  6.389   48.0  4.7794    3  247
# 416  10.83420   0.0  18.10     0  0.679  6.782   90.8  1.8195   24  666
# 363   4.22239   0.0  18.10     1  0.770  5.803   89.0  1.9047   24  666
# 393   8.64476   0.0  18.10     0  0.693  6.193   92.6  1.7912   24  666
#
#      ptratio   black
# 439     20.2  396.90
# 118     17.8  338.63
# 348     17.0  390.94
# 385     20.2  396.90
# 129     21.2  396.90
# ..       ...     ...
# 371     20.2  366.15
# 84      18.5  396.90
# 416     20.2   21.57
# 363     20.2  353.04
# 393     20.2  396.90
#
# [167 rows x 12 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_train, y_train)
# Out:
# 0.6983353541140622

# %%
reg.score(X_test, y_test)
# Out:
# 0.6289030960212194

# %%
reg.predict(X_test)
# Out:
# array([15.37225696, 21.14097658, 27.60203957, 13.39317133, 14.14386708,
#        35.43783898, 22.42199791, 28.0685816 , 27.75759988, 15.83090537,
#        21.3388415 , 16.23773093, 19.65779593, 16.09257552, 38.28762393,
#        25.26871754, 40.3202323 , 24.84063496, 26.28815589, 22.11636597,
#        34.14911483, 30.70993208, 16.03022989, 24.09524102, 17.96958062,
#        23.16414565, 37.62870441, 15.2370801 , 16.74331369, 13.8140411 ,
#        15.74043382, 33.64572549, 19.75669525, 16.94685017, 19.07062885,
#        22.04713198, 18.31312142, 28.21107075, 15.37055878, 20.06466238,
#        32.03841169, 22.18124122, 27.8578637 , 29.29487557, 22.24621565,
#        22.71357796, 20.60149261, 21.29233002, 14.86939384, 26.66088343,
#        23.19764145, 21.22821046, 23.79816582, 10.19173623, 23.08028147,
#        17.60722048, 16.22488162, 33.13025032, 19.22539077, 17.4878229 ,
#        20.32606507, 17.70869793, 18.9804368 , 18.10068354, 13.83065668,
#        21.19493169, 27.76206247, 30.87898954, 19.35243866, 36.78092721,
#        20.29178123, 24.84612551, 24.33310526, 23.23570935, 21.26407045,
#        26.80788664, 22.32656865, 28.98818618, 28.49391255, 15.51754451,
#        19.59323946, 24.1306983 , 35.8443135 , 21.95363989, 26.71962844,
#        15.41784628, 25.99186941, 35.91718017, 23.73612997, 26.33626987,
#        29.11122192, 18.07088076, 20.25420468, 31.32380821, 19.01779073,
#        20.57843637, 26.89474773, 21.83931279, 23.20654621, 23.96709551,
#        24.81573283, 18.8001888 , 20.68420301, 37.28033978, 21.61676472,
#        12.97907877, 26.28405724, 12.79235805, 15.71323792, 11.06941313,
#        28.83758801, 21.48672341, 25.49119811, 20.44207572, 32.49660498,
#        21.14114297, 21.72204379, 19.01821986, 30.31082443,  9.42405249,
#        16.65140511, 21.57080586, 22.56572214, 41.37414705, 27.75903954,
#        20.58875706, 18.92265757, 30.33236663, 12.13854963, 20.85329343,
#        36.61550158, 17.13793502,  6.77422849, 20.92275269,  7.64295277,
#        20.46044236, 16.07824878, 24.23206977, 12.3943343 , 28.23578733,
#        23.59695185, 21.02845738, 20.05954537, 24.71202659, 19.89484039,
#        23.65716267, 19.12538182, 17.74848237, 20.40693186, 29.14405809,
#        17.11983498, 19.29506727, 20.01244687, 21.34770174, 27.44279218,
#        18.3725085 , 23.41324556, 23.57169062, 13.46051916, 24.95193874,
#        21.71180393, 12.97334766, 21.02872296, 25.54376668, 18.39063829,
#        20.20329732, 19.65979865])

# %%
plt.scatter(y_test,reg.predict(X_test),c = 'green')

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn import metrics

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(reg, X, Y, cv=5)
# Out:
# array([ 0.69227756,  0.63910471,  0.52545216, -0.07401188, -1.20282723])

# %% [markdown]
# ## including only Rm in the model

# %%
rm = df.iloc[:,5]

# %%
rm = rm.values.reshape(-1,1)

# %%
Y = Y.values.reshape(-1,1)

# %%
X_train,X_test,y_train,y_test = train_test_split(rm,Y,test_size=0.33)

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_train, y_train)
# Out:
# 0.3978575434972196

# %%
reg.score(X_test, y_test)
# Out:
# 0.6144895723618873

# %%
reg.predict(X_test)
# Out:
# array([[19.423081  ],
#        [10.99278417],
#        [21.71837437],
#        [21.92315891],
#        [22.96414698],
#        [35.13176164],
#        [ 3.86798876],
#        [19.61080016],
#        [17.72507587],
#        [20.25928453],
#        [29.6793733 ],
#        [21.40266487],
#        [23.52730446],
#        [18.88552159],
#        [25.12291732],
#        [25.2935711 ],
#        [20.83950739],
#        [26.41988606],
#        [19.92650966],
#        [19.91797697],
#        [18.8001947 ],
#        [17.5458894 ],
#        [23.91127547],
#        [18.51008327],
#        [ 3.86798876],
#        [31.12993045],
#        [19.423081  ],
#        [35.37920962],
#        [16.37691099],
#        [23.39078143],
#        [21.47945907],
#        [36.21541316],
#        [18.16024301],
#        [16.6072936 ],
#        [14.55091552],
#        [17.9383931 ],
#        [27.0939685 ],
#        [24.69628287],
#        [20.46406907],
#        [18.16024301],
#        [21.25760916],
#        [21.56478596],
#        [19.51694058],
#        [18.68926974],
#        [25.69460749],
#        [42.82824721],
#        [17.27284335],
#        [16.45370519],
#        [28.63838523],
#        [20.71151705],
#        [18.55274671],
#        [17.46056251],
#        [27.18782808],
#        [ 8.25379096],
#        [43.00743368],
#        [21.80370126],
#        [18.76606394],
#        [17.26431066],
#        [24.44030219],
#        [18.51008327],
#        [22.44365294],
#        [20.54086327],
#        [28.08376044],
#        [35.56692878],
#        [26.42841875],
#        [18.8001947 ],
#        [37.40998963],
#        [25.54101909],
#        [28.01549893],
#        [22.59724135],
#        [21.05282462],
#        [34.81605214],
#        [24.15872345],
#        [14.67037317],
#        [19.44014638],
#        [19.26095991],
#        [27.92163935],
#        [19.3462868 ],
#        [29.54285028],
#        [18.68073705],
#        [30.02068087],
#        [21.30880529],
#        [23.62116404],
#        [22.61430672],
#        [25.95058816],
#        [18.62954091],
#        [25.13145001],
#        [23.62969673],
#        [31.07873432],
#        [23.15186614],
#        [10.39549593],
#        [27.87044321],
#        [21.89756084],
#        [27.8021817 ],
#        [17.3069741 ],
#        [17.68241242],
#        [21.73543975],
#        [29.20154271],
#        [12.01670686],
#        [23.10920269],
#        [25.01199236],
#        [ 7.11894331],
#        [21.55625328],
#        [23.2627911 ],
#        [20.02036924],
#        [12.54573358],
#        [24.66215211],
#        [15.75402469],
#        [20.10569613],
#        [21.40266487],
#        [31.34324768],
#        [23.80035051],
#        [24.81574051],
#        [23.01534311],
#        [14.86662502],
#        [23.21159496],
#        [24.5938906 ],
#        [10.59174778],
#        [22.53751252],
#        [26.71853018],
#        [18.64660629],
#        [19.46574445],
#        [26.25776497],
#        [15.21646527],
#        [17.04246074],
#        [21.13815151],
#        [18.86845621],
#        [19.14150226],
#        [10.90745727],
#        [20.98456311],
#        [13.81710426],
#        [20.61765747],
#        [11.53034358],
#        [36.16421702],
#        [32.16238583],
#        [25.17411346],
#        [19.32922142],
#        [25.1399827 ],
#        [37.11134551],
#        [31.83814365],
#        [16.48783595],
#        [20.57499403],
#        [22.41805488],
#        [21.84636471],
#        [16.41104175],
#        [ 5.83050726],
#        [19.48280982],
#        [17.68241242],
#        [19.13296957],
#        [17.89572965],
#        [28.07522775],
#        [22.23033571],
#        [34.1419697 ],
#        [20.72004974],
#        [16.57316284],
#        [24.34644261],
#        [30.56677297],
#        [28.3482738 ],
#        [20.01183655],
#        [24.83280589],
#        [29.61111179],
#        [19.59373478],
#        [23.12626807],
#        [23.38224874],
#        [14.20107527],
#        [16.65848973],
#        [39.03120056]])

# %%
plt.scatter(y_test,reg.predict(X_test),c = 'green')

# %%
cross_val_score(reg, rm, Y, cv=5)
# Out:
# array([ 0.70708692,  0.63476138,  0.50385441, -0.21594318, -1.77736913])
